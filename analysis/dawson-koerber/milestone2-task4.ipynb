# %% [markdown]
# ## Task 4. Conduct your analysis to help answer your research question(s)
#
# ### Research Question:
# What is the average increase in cost smokers pay as compared to their non-smoking counterpoint?

# %%
#Import wrangled data and creat relevant plots
from scriptz import project_functions as pf # This is called a relative import
df = pf.wranglemania2K21("../../data/raw/insurance.csv")
pf.plots(df)

# %% [markdown]
# ## Analysis
#
# Initial thoughts on this matter included that of the idea that smoking might affect ones BMI, which would in turn be related to their medical charges. However, it was determined that smoking and BMI have no substantial correlation. After removing BMI from the equation, we were able to focus on the fundamental factors of whether or not one smokes, and how much their medical charges were. When distributing this relationship it was disparagingly obvious the most non-smokers were paying less than 10000 dollars in medical charges. For smokers however, this was simply their charges started. Furthermore, it was found that a non-smoker pays 8451 dollars in medical charges on average. A smoker however, pays 31744 dollars on average. That's 23293 dollars more than a non-smoker! In conclusion, it is beyond a shadow of doubt that smoking has direct correlation with increased medical costs.
